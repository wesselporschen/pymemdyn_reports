# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd

from interface import PymemdynReport

# %%
Report_4YK5 = PymemdynReport('./reports/4YK5')

# %%
Report_4YK5.plot()

# %% [markdown]
# In the `rmsf-per-residue`-plot, the residues of the mPGES-1 trimer have been reindexed:
# - Monomer 1: res 1-149
# - Monomer 2: res 201-349
# - Monomer 3: res 401-549

# %% [markdown]
# Trajectories of system parameters
#
# The PyMemDyn protocol involves several relaxation / equilibration steps. Since mPGES-1 is not a GPCR, the last relaxation stage featured restraints on the C-alpha atoms, as opposed to the Ballesteros-Weinstein numbered atoms as with the GPCRs.
#
# | Stage | Restrained Atoms | Force constant (kJ mol^-1 Ä^-1 nm^2) | Time (ns) |
# |---|---|---|---|
# | Minimization |  |  | (Max 500 steps) |
# | 1 | Protein Heavy Atoms | 1000 | 0.5 |
# | 2 | Protein Heavy Atoms | 800 | 0.5 |
# | 3 | Protein Heavy Atoms | 600 | 0.5 |
# | 4 | Protein Heavy Atoms | 200 | 0.5 |
# | 5 | Protein Heavy Atoms | 200 | 0.5 |
# | Relaxation | C-alpha atoms | 200 | 2.5 |
